# %% [markdown]
# <a href="https://colab.research.google.com/github/burzin25/2021Fall_finals/blob/main/Hypothesis_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hypothesis 4: Toss decision directly contributes to the result of the game.

# %% [markdown]
# Please refer to .py file of this hypothesis for code quality review.

# %% [markdown]
# Author : Burzin Wadia
# ---
# Net ID : bwadia2

# %%
# Importing Libraries
import pandas as pd
import plotly
import plotly.express as px
import numpy as np
from pandas import DataFrame

# %%
# Defining User Parameters

# Which IPL season do you want to check the statistics for ?
season = 2018

# Reading csv file
toss_df = pd.read_csv("https://raw.githubusercontent.com/Venkat3103/2022Fall_projects/main/ipl_match_info.csv",
                      usecols=['Team1', 'Team2', 'date', 'venue', 'toss_winner', 'toss_decision',
                                'match_winner', 'year'])

# %%
def process(unprocessed_df: DataFrame, season: int) -> pd.DataFrame:
    """
    This function takes in Raw DataFrame and year from the user and filters the DataFrame to keep data related to the
    year 2018.

    param unprocessed_df: The Raw DataFrame consisting of data related to Team1 VS Team2, toss_winner, toss_decision, match_winner, year.
    :param season: The season year that the needs to be filtered for.
    :return: Processed or filtered DataFrame wrt year.

    >>> x = pd.read_csv("ipl_match_info.csv", usecols=['Team1', 'Team2', 'date', 'venue', 'toss_winner', 'toss_decision','match_winner', 'year'])
    >>> process(x,2018) # doctest: +ELLIPSIS
                              Team1  ...  year
    0                Mumbai Indians  ...  2018
    1              Delhi Daredevils  ...  2018
    ...

    >>> t_df = pd.DataFrame({"Team1":["Mumbai Indians","Kolkata Knight Riders", "Kings XI Punjab","Royal Challengers Bangalore", "Royal Challengers Bangalore", "Delhi Capitals"] , "Team2":["Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Rajasthan Royals"], "date":["2018-04-07","2018-04-10","2018-04-15", "2018-04-25", "2018-05-05", "2019-05-18"], "venue":["Wankhede Stadium","MA Chidambaram Stadium", "Punjab Cricket Association IS Bindra Stadium","M.Chinnaswamy Stadium","Maharashtra Cricket Association Stadium","Arun Jaitley Stadium"], "toss_winner":["Chennai Super Kings", "Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings"], "toss_decision":["field","field","field","field","field","field"], "match_winner":["Chennai Super Kings","Chennai Super Kings","Kings XI Punjab","Chennai Super Kings","Chennai Super Kings","Delhi Capitals"], "year":[2018,2018,2018,2018,2018,2019]})
    >>> len(process(t_df, 2018))
    5

    >>> len(process(t_df, 2019))
    1

    >>> t = process(t_df, 2018)
    >>> type(t["year"][0])
    <class 'numpy.int64'>

    """
    if season != "all":
        unprocessed_df = unprocessed_df[unprocessed_df["year"] == season]

    else:
        # Preprocess Data for all the year
        unprocessed_df['Team1'] = unprocessed_df['Team1'].replace(['Delhi Daredevils'], 'Delhi Capitals')
        unprocessed_df['Team2'] = unprocessed_df['Team2'].replace(['Delhi Daredevils'], 'Delhi Capitals')
        unprocessed_df['toss_winner'] = unprocessed_df['toss_winner'].replace(['Delhi Daredevils'], 'Delhi Capitals')
        unprocessed_df['match_winner'] = unprocessed_df['match_winner'].replace(['Delhi Daredevils'], 'Delhi Capitals')

    return unprocessed_df

# %%
# Variable to store the filtered DataFrame as returned by the process()
process_df = process(toss_df, season)
process_df
# Out:
#                           Team1                        Team2        date  \
# 0                Mumbai Indians          Chennai Super Kings  2018-04-07
# 44                          Arun Jaitley Stadium  Royal Challengers Bangalore
# 45                              Wankhede Stadium             Rajasthan Royals
# 46       Maharashtra Cricket Association Stadium          Chennai Super Kings
# 47                        Holkar Cricket Stadium  Royal Challengers Bangalore
# 48                                  Eden Gardens        Kolkata Knight Riders
# 49                              Wankhede Stadium              Kings XI Punjab
# 50                         M.Chinnaswamy Stadium          Sunrisers Hyderabad
# 51                          Arun Jaitley Stadium          Chennai Super Kings
# 52                        Sawai Mansingh Stadium             Rajasthan Royals
# 53            Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 54       Maharashtra Cricket Association Stadium          Chennai Super Kings
# 55                          Arun Jaitley Stadium             Delhi Daredevils
# 56                              Wankhede Stadium          Chennai Super Kings
# 57                                  Eden Gardens             Rajasthan Royals
# 58                                  Eden Gardens        Kolkata Knight Riders
# 59                              Wankhede Stadium          Chennai Super Kings
#
#    toss_decision                 match_winner  year
# 0          field          Chennai Super Kings  2018
# 1          field              Kings XI Punjab  2018
# 2          field        Kolkata Knight Riders  2018
# 3          field          Sunrisers Hyderabad  2018
# 4          field          Chennai Super Kings  2018
# 5          field             Rajasthan Royals  2018
# 6          field          Sunrisers Hyderabad  2018
# 7          field  Royal Challengers Bangalore  2018
# 8          field          Sunrisers Hyderabad  2018
# 9          field             Delhi Daredevils  2018
# 10         field             Rajasthan Royals  2018
# 11         field              Kings XI Punjab  2018
# 12         field        Kolkata Knight Riders  2018
# 13         field               Mumbai Indians  2018
# 14         field        Kolkata Knight Riders  2018
# 15           bat              Kings XI Punjab  2018
# 16         field          Chennai Super Kings  2018
# 17         field  Royal Challengers Bangalore  2018
# 18         field              Kings XI Punjab  2018
# 19           bat             Rajasthan Royals  2018
# 20         field          Chennai Super Kings  2018
# 21         field              Kings XI Punjab  2018
# 22         field          Sunrisers Hyderabad  2018
# 23         field          Chennai Super Kings  2018
# 24         field          Sunrisers Hyderabad  2018
# 25         field             Delhi Daredevils  2018
# 26         field               Mumbai Indians  2018
# 27         field        Kolkata Knight Riders  2018
# 28           bat          Sunrisers Hyderabad  2018
# 29         field          Chennai Super Kings  2018
# 30         field  Royal Challengers Bangalore  2018
# 31         field             Delhi Daredevils  2018
# 32         field        Kolkata Knight Riders  2018
# 33         field               Mumbai Indians  2018
# 34           bat          Sunrisers Hyderabad  2018
# 35         field          Chennai Super Kings  2018
# 36         field               Mumbai Indians  2018
# 37         field              Kings XI Punjab  2018
# 38         field          Sunrisers Hyderabad  2018
# 39           bat             Rajasthan Royals  2018
# 40         field               Mumbai Indians  2018
# 41           bat          Sunrisers Hyderabad  2018
# 42           bat             Rajasthan Royals  2018
# 43         field        Kolkata Knight Riders  2018
# 44         field  Royal Challengers Bangalore  2018
# 45         field             Rajasthan Royals  2018
# 46         field          Chennai Super Kings  2018
# 47         field  Royal Challengers Bangalore  2018
# 48         field        Kolkata Knight Riders  2018
# 49         field               Mumbai Indians  2018
# 50         field  Royal Challengers Bangalore  2018
# 51         field             Delhi Daredevils  2018
# 52           bat             Rajasthan Royals  2018
# 53           bat        Kolkata Knight Riders  2018
# 54         field          Chennai Super Kings  2018
# 55           bat             Delhi Daredevils  2018
# 56         field          Chennai Super Kings  2018
# 57         field        Kolkata Knight Riders  2018
# 58         field          Sunrisers Hyderabad  2018
# 59         field          Chennai Super Kings  2018

# %%
def overall_plot(processed_df: DataFrame, season: int) -> DataFrame:
    """
    This function will use the Processed DataFrame from process() and plot data showing the number of matches won by each team based on the individual decision

    param processed_df: Input DataFrame which is the output of process() and also a filtered by year DataFrame
    :param season: The season year that the needs to be filtered for.
    :return: A bar chart and a dataframe

    >>> t_df = pd.DataFrame({"Team1":["Mumbai Indians","Kolkata Knight Riders", "Kings XI Punjab","Royal Challengers Bangalore", "Royal Challengers Bangalore", "Delhi Capitals"] , "Team2":["Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Rajasthan Royals"], "date":["2018-04-07","2018-04-10","2018-04-15", "2018-04-25", "2018-05-05", "2019-05-18"], "venue":["Wankhede Stadium","MA Chidambaram Stadium", "Punjab Cricket Association IS Bindra Stadium","M.Chinnaswamy Stadium","Maharashtra Cricket Association Stadium","Arun Jaitley Stadium"], "toss_winner":["Chennai Super Kings", "Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings"], "toss_decision":["field","field","field","field","field","field"], "match_winner":["Chennai Super Kings","Chennai Super Kings","Kings XI Punjab","Chennai Super Kings","Chennai Super Kings","Delhi Capitals"], "year":[2018,2018,2018,2018,2018,2018]})
    >>> x,y = overall_plot(t_df, 2018)
    >>> y
              Match Winner toss_decision  Number of Matches Won
    0  Chennai Super Kings         field                      4
    1       Delhi Capitals         field                      1
    2      Kings XI Punjab         field                      1

    >>> y["toss_decision"].unique().tolist()
    ['field']

    """
    # Number of Toss won by each Team during the IPL Season of 2018, 2019, 2020

    match_won = pd.DataFrame(processed_df.groupby(["match_winner", "toss_decision"])["match_winner"].count())
    match_won = match_won.rename(columns={'match_winner': 'Number of Matches Won'})
    match_won.reset_index(inplace=True)
    match_won = match_won.rename(columns={'match_winner': "Match Winner"})
    match_won.head()

    colors = plotly.colors.qualitative.Prism
    fig = px.bar(match_won, x='Match Winner', y='Number of Matches Won', color='toss_decision',
                 text=match_won['Number of Matches Won'].astype(str), color_discrete_sequence=colors)
    fig.update_layout(title_text=f'Toss Decision vs Matches Won for :  {season} Season')

    return fig.show(), match_won

# %%
ov_plot, ov_df = overall_plot(toss_df, season)
ov_plot
print(ov_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="985ba25d-8379-4fe9-9e84-7aa8c31c235e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("985ba25d-8379-4fe9-9e84-7aa8c31c235e")) {                    Plotly.newPlot(                        "985ba25d-8379-4fe9-9e84-7aa8c31c235e",                        [{"alignmentgroup":"True","hovertemplate":"toss_decision=bat<br>Match Winner=%{x}<br>Number of Matches Won=%{y}<br>text=%{text}<extra></extra>","legendgroup":"bat","marker":{"color":"rgb(95, 70, 144)","pattern":{"shape":""}},"name":"bat","offsetgroup":"bat","orientation":"v","showlegend":true,"text":["5","5","1","3","4","8","7","5","7"],"textposition":"auto","x":["Chennai Super Kings","Delhi Capitals","Delhi Daredevils","Kings XI Punjab","Kolkata Knight Riders","Mumbai Indians","Rajasthan Royals","Royal Challengers Bangalore","Sunrisers Hyderabad"],"xaxis":"x","y":[5,5,1,3,4,8,7,5,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"toss_decision=field<br>Match Winner=%{x}<br>Number of Matches Won=%{y}<br>text=%{text}<extra></extra>","legendgroup":"field","marker":{"color":"rgb(29, 105, 150)","pattern":{"shape":""}},"name":"field","offsetgroup":"field","orientation":"v","showlegend":true,"text":["22","12","4","14","17","19","11","12","17"],"textposition":"auto","x":["Chennai Super Kings","Delhi Capitals","Delhi Daredevils","Kings XI Punjab","Kolkata Knight Riders","Mumbai Indians","Rajasthan Royals","Royal Challengers Bangalore","Sunrisers Hyderabad"],"xaxis":"x","y":[22,12,4,14,17,19,11,12,17],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...
#                    Match Winner toss_decision  Number of Matches Won
# 0           Chennai Super Kings           bat                      5
# 1           Chennai Super Kings         field                     22
# 2                Delhi Capitals           bat                      5
# 3                Delhi Capitals         field                     12
# 4              Delhi Daredevils           bat                      1
# 5              Delhi Daredevils         field                      4
# 6               Kings XI Punjab           bat                      3
# 7               Kings XI Punjab         field                     14
# 8         Kolkata Knight Riders           bat                      4
# 9         Kolkata Knight Riders         field                     17
# 10               Mumbai Indians           bat                      8
# 11               Mumbai Indians         field                     19
# 12             Rajasthan Royals           bat                      7
# 13             Rajasthan Royals         field                     11
# 14  Royal Challengers Bangalore           bat                      5
# 15  Royal Challengers Bangalore         field                     12
# 16          Sunrisers Hyderabad           bat                      7
# 17          Sunrisers Hyderabad         field                     17

# %%
def toss_plot(processed_df: DataFrame, season: int) -> DataFrame:
    """
    This functions takes the filtered DataFrame as input and plots a piechart of Toss won  vs % matches won and loss.

    param processed_df: Input Filtered DataFrame from process()
    :param season: The season year that the needs to be filtered for.
    :return: A pie chart and a dataframe

    >>> tp_df = pd.DataFrame({"Team1":["Mumbai Indians","Kolkata Knight Riders", "Kings XI Punjab","Royal Challengers Bangalore", "Royal Challengers Bangalore", "Delhi Capitals"] , "Team2":["Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Rajasthan Royals"], "date":["2018-04-07","2018-04-10","2018-04-15", "2018-04-25", "2018-05-05", "2019-05-18"], "venue":["Wankhede Stadium","MA Chidambaram Stadium", "Punjab Cricket Association IS Bindra Stadium","M.Chinnaswamy Stadium","Maharashtra Cricket Association Stadium","Arun Jaitley Stadium"], "toss_winner":["Chennai Super Kings", "Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings"], "toss_decision":["field","field","field","field","field","field"], "match_winner":["Chennai Super Kings","Chennai Super Kings","Kings XI Punjab","Chennai Super Kings","Chennai Super Kings","Delhi Capitals"], "year":[2018,2018,2018,2018,2018,2018]})
    >>> x,y = toss_plot(tp_df, 2018)
    >>> y
                              Toss_Won  count
    0  Won the Toss and Lost the Match      2
    1   Won the Toss and Won the Match      4

    >>> type(y["count"][0])
    <class 'numpy.int64'>

    """

    winner_toss = pd.DataFrame(processed_df[["toss_winner", "match_winner"]])

    winner_toss['Toss_Won'] = np.where((winner_toss['toss_winner'] == winner_toss['match_winner']), "Won the Toss and "
                                                                                                    "Won the Match",
                                       np.where((winner_toss['toss_winner'] != winner_toss['match_winner']),
                                                "Won the Toss and Lost the Match",
                                                np.nan))
    count_df = pd.DataFrame(winner_toss.groupby("Toss_Won")["Toss_Won"].count())
    count_df.rename(columns={"Toss_Won": "count"}, inplace=True)
    count_df.reset_index(inplace=True)

    fig = px.pie(count_df, values="count", names='Toss_Won')

    fig.update_layout(title_text=f'Toss results vs % of Matches Won for :  {season} Season')

    return fig.show(), count_df

# %%
t_plot,t_df = toss_plot(process_df, season)
t_plot
print(t_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b9977c2c-0a02-4831-9b78-114ee2447d8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9977c2c-0a02-4831-9b78-114ee2447d8c")) {                    Plotly.newPlot(                        "b9977c2c-0a02-4831-9b78-114ee2447d8c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Toss_Won=%{label}<br>count=%{value}<extra></extra>","labels":["Won the Toss and Lost the Match","Won the Toss and Won the Match"],"legendgroup":"","name":"","showlegend":true,"values":[28,32],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...
#                           Toss_Won  count
# 0  Won the Toss and Lost the Match     28
# 1   Won the Toss and Won the Match     32

# %%
def decision_plot(process_data: DataFrame, season: int) -> DataFrame:
    """
    This functions takes the filtered DataFrame as input and plots a piechart of Winning Toss Decision vs % matches won
    and loss.

    param process_data: Input Filtered DataFrame from process()
    :param season: The season year that the needs to be filtered for.
    :return: A pie chart and a dataframe

    >>> dp_df = pd.DataFrame({"Team1":["Mumbai Indians","Kolkata Knight Riders", "Kings XI Punjab","Royal Challengers Bangalore", "Royal Challengers Bangalore", "Delhi Capitals"] , "Team2":["Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Chennai Super Kings", "Rajasthan Royals"], "date":["2018-04-07","2018-04-10","2018-04-15", "2018-04-25", "2018-05-05", "2019-05-18"], "venue":["Wankhede Stadium","MA Chidambaram Stadium", "Punjab Cricket Association IS Bindra Stadium","M.Chinnaswamy Stadium","Maharashtra Cricket Association Stadium","Arun Jaitley Stadium"], "toss_winner":["Chennai Super Kings", "Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings","Chennai Super Kings"], "toss_decision":["field","field","field","field","field","field"], "match_winner":["Chennai Super Kings","Chennai Super Kings","Kings XI Punjab","Chennai Super Kings","Chennai Super Kings","Delhi Capitals"], "year":[2018,2018,2018,2018,2018,2018]})
    >>> x, y = decision_plot(dp_df, 2018)
    >>> y
                                    Bat_Won  count
    0                        Lost the Toss       2
    1  Won the toss and chose to Bat Second      4

    >>> print(type(y))
    <class 'pandas.core.frame.DataFrame'>

    """

    # % of games a team chose batting first, won the match
    winner_bat = pd.DataFrame(process_data[["Team1", "Team2", "toss_winner", "toss_decision", "match_winner"]])

    winner_bat['Bat_Won'] = np.where((winner_bat['toss_winner'] == winner_bat['match_winner']) & (
            winner_bat['toss_decision'] == "bat"), "Won the toss and chose to Bat First",
                                     np.where((winner_bat['toss_winner'] == winner_bat['match_winner']),
                                              "Won the toss and chose to Bat Second", " Lost the Toss "))
    winner_bat.dropna(inplace=True)
    count_df = pd.DataFrame(winner_bat.groupby("Bat_Won")["Bat_Won"].count())

    count_df.rename(columns={"Bat_Won": "count"}, inplace=True)

    count_df.reset_index(inplace=True)

    fig = px.pie(count_df, values="count", names='Bat_Won')

    fig.update_layout(title_text=f'Winning Toss Decision vs % of Matches Won for :  {season} Season')

    return fig.show(), count_df

# %%
d_plot,d_df = decision_plot(process_df, season)
print(d_df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="793fb90d-7405-4a8d-a80e-8844db00d12a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("793fb90d-7405-4a8d-a80e-8844db00d12a")) {                    Plotly.newPlot(                        "793fb90d-7405-4a8d-a80e-8844db00d12a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Bat_Won=%{label}<br>count=%{value}<extra></extra>","labels":[" Lost the Toss ","Won the toss and chose to Bat First","Won the toss and chose to Bat Second"],"legendgroup":"","name":"","showlegend":true,"values":[28,5,27],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{ ...
#                                 Bat_Won  count
# 0                        Lost the Toss      28
# 1   Won the toss and chose to Bat First      5
# 2  Won the toss and chose to Bat Second     27

# %% [markdown]
# Conclusion :
#  Hypothesis 4 stands True
